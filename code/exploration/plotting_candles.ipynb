# %%
import pandas as pd
import plotly.graph_objects as go
import datetime as dt

# %%
pair = "EUR_USD"
granularity = "H4"
df = pd.read_pickle(f"../data/{pair}_{granularity}.pkl")

# %%
df.tail()
# Out:
#                           time  volume    mid_o    mid_h    mid_l    mid_c  \
# 3995 2023-07-07 17:00:00+00:00    9037  1.09718  1.09733  1.09633  1.09688
# 3996 2023-07-09 21:00:00+00:00    5444  1.09610  1.09698  1.09570  1.09644
# 3997 2023-07-10 01:00:00+00:00   11477  1.09642  1.09695  1.09528  1.09531
# 3998 2023-07-10 05:00:00+00:00   15118  1.09532  1.09658  1.09451  1.09648
# 3999 2023-07-10 09:00:00+00:00   14956  1.09647  1.09733  1.09436  1.09470
#
#         bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l    ask_c  \
# 3995  1.09710  1.09726  1.09625  1.09675  1.09727  1.09741  1.09641  1.09701
# 3996  1.09583  1.09689  1.09553  1.09636  1.09638  1.09716  1.09578  1.09652
# 3997  1.09634  1.09688  1.09519  1.09523  1.09649  1.09702  1.09536  1.09539
# 3998  1.09525  1.09650  1.09444  1.09641  1.09540  1.09666  1.09458  1.09656
# 3999  1.09640  1.09725  1.09428  1.09463  1.09654  1.09741  1.09444  1.09478
#
#                 sTime
# 3995  s23-07-07 17:00
# 3996  s23-07-09 21:00
# 3997  s23-07-10 01:00
# 3998  s23-07-10 05:00
# 3999  s23-07-10 09:00

# %%
df['sTime'] = [dt.datetime.strftime(x, "s%y-%m-%d %H:%M") for x in df.time]

# %%
df_plot = df.iloc[:100]

# %%
fig = go.Figure()
fig.add_trace(go.Candlestick(
    x=df_plot.sTime,
    open=df_plot.mid_o,
    high=df_plot.mid_h,
    low=df_plot.mid_l,
    close=df_plot.mid_c,
    line=dict(width=1), opacity=1,
    increasing_fillcolor='#24A06B',
    decreasing_fillcolor='#CC2E3C',
    increasing_line_color='#2EC886',
    decreasing_line_color='#FF3A4C'
))

fig.update_yaxes(
    gridcolor="#1f292f"
)
fig.update_xaxes(
    gridcolor="#1f292f",
    rangeslider=dict(visible=False),
    nticks = 5
)

fig.update_layout(
    width=900,
    height=400,
    margin=dict(l=10,r=10,b=10,t=10),
    paper_bgcolor="#2c303c",
    plot_bgcolor="#2c303c",
    font=dict(size=8, color="#e1e1e1")
)

fig.show()
# Out:
# <div>                            <div id="01e04569-11bc-43a0-82d5-baee12de6988" class="plotly-graph-div" style="height:400px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
,1.21725,1.21842,1.2202,1.21872,1.21858,1.21774,1.2178,1.21812,1.22044,1.22198,1.21914,1.22052,1.22027,1.22086,1.22247,1.22359,1.22392,1.22372,1.22361,1.22495,1.22818,1.22528,1.22664,1.22712,1.22806,1.22935,1.22853,1.2277,1.22596,1.22211,1.22094,1.2231,1.22415,1.22422,1.22864,1.22501,1.22414,1.2247,1.2257,1.22553,1.22604,1.2254,1.22896,1.2281,1.22757,1.22966,1.23168,1.22656,1.22966,1.23248,1.2311,1.22641,1.22451,1.22464,1.2263,1.2235,1.22458,1.22134,1.22324],"opacity":1,"open":[1.21436,1.216,1.21547,1.21578,1.21396,1.21609,1.21522,1.21512,1.21624,1.22062,1.21879,1.21687,1.21991,1.22024,1.2226,1.22325,1.22418,1.22602,1.22678,1.22565,1.22434,1.22494,1.22487,1.22368,1.22221,1.22082,1.21913,1.21755,1.21916,1.22362,1.2243,1.22312,1.22186,1.22074,1.22302,1.21746,1.2163,1.21771,1.2189,1.2194,1.21762,1.2187,1.21873,1.22083,1.22052,1.21916,1.21881,1.21836,1.21892,1.22051,1.22236,1.2249,1.22131,1.22064,1.22145,1.22276,1.22362,1.22499,1.22537,1.22416,1.22508,1.22911,1.2285,1.22686,1.22914,1.22888,1.22979,1.23065,1.22896,1.22792,1.22846,1.22254,1.224,1.22526,1.22556,1.22932,1.2299,1.22528,1.22525,1.22574,1.22722,1.22726,1.22628,1.22996,1.22986,1.22895,1.22966,1.23384,1.23198,1.22989,1.23264,1.23308,1.23127,1.22688,1.22684,1.22659,1.22729,1.2248,1.22579,1.22407],"x":["s20-12-14 22:00","s20-12-15 02:00","s20-12-15 06:00","s20-12-15 10:00","s20-12-15 14:00","s20-12-15 18:00","s20-12-15 22:00","s20-1 ...

# %%
 df_ma = df[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c']].copy()

# %%
df_ma['MA_10'] = df_ma.mid_c.rolling(window=10).mean()
df_ma.dropna(inplace=True)
df_ma.reset_index(inplace=True, drop=True)

# %%
df_ma.head()
# Out:
#                        time    mid_o    mid_h    mid_l    mid_c     MA_10
# 0 2020-12-17 22:00:00+00:00  1.22678  1.22719  1.22506  1.22564  1.222445
# 1 2020-12-18 02:00:00+00:00  1.22565  1.22586  1.22386  1.22434  1.223001
# 2 2020-12-18 06:00:00+00:00  1.22434  1.22630  1.22429  1.22496  1.223809
# 3 2020-12-18 10:00:00+00:00  1.22494  1.22688  1.22433  1.22486  1.224297
# 4 2020-12-18 14:00:00+00:00  1.22487  1.22535  1.22257  1.22366  1.224639
